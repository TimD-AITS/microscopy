# %% [markdown]
# # **SETUP**
#
# 1) continue Image Classification problem from previous class which aims to classify microscopy images into good, empty or blurred by:
# 1. gathering ~1000 samples per class for training the model;
# 2. using https://supervise.ly for image augmentation to generate more samples;
# 3. using CNN and transfer learning
#
# 2) denoise blurred images using auto-encoder
# 1. please see https://blog.keras.io/building-autoencoders-in-keras.html
# 2. Simple structure could be: blurry input images -> feed into CNN (this could be transfer learning) -> train x - noise image  y - clean image -> Fully connected NN -> reconstructed clean image
#
# 3) track patches from fluorescence images and use a visualization tool

# %%
# %tensorflow_version 1.x
import tensorflow as tf
import keras
from platform import python_version
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %%
keras.__version__
# Out:
# '2.2.5'

# %%
tf.__version__
# Out:
# '1.15.2'

# %%
print(python_version())
# Out:
# 3.6.9

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.models import Model
from keras import applications
import tensorflow as tf
from tqdm import tqdm
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.optimizers import Adam,SGD,Adagrad,Adadelta,RMSprop
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping
import random
from shutil import copyfile
import os
import gc
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from keras import backend as K

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib import style
import seaborn as sns
from keras.callbacks import ModelCheckpoint
#configure
# sets matplotlib to inline and displays graphs below the corressponding cell.
# %matplotlib inline  
style.use('fivethirtyeight')
sns.set(style='whitegrid',color_codes=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/DeepLearning/Project/dataset2/

# !ls
# Out:
# /content/drive/My Drive/DeepLearning/Project/dataset2
# blurred  empty	good  test  train  train1  val	VGG16_model3.h5

# %%
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
# %matplotlib inline
# Where to save the figures
PROJECT_ROOT_DIR = "."
import os
import numpy as np
import shutil

# %%
 # Creating Train / Val / Test folders (One time use)
images_split = "/content/drive/My Drive/DeepLearning/Project/dataset2"
good = "/good"
empty = "/empty"
blurred = "/blurred"

if os.path.exists(images_split +'/train' + good):
    shutil.rmtree(images_split +'/train' + good)
os.makedirs(images_split +'/train' + good)

if os.path.exists(images_split +'/train1' + good):
    shutil.rmtree(images_split +'/train1' + good)
os.makedirs(images_split +'/train1' + good)

if os.path.exists(images_split +'/test' + good):
    shutil.rmtree(images_split +'/test' + good)
os.makedirs(images_split +'/test' + good)

if os.path.exists(images_split +'/val' + good):
    shutil.rmtree(images_split +'/val' + good)
os.makedirs(images_split +'/val' + good)

if os.path.exists(images_split +'/train' + empty):
    shutil.rmtree(images_split +'/train' + empty)
os.makedirs(images_split +'/train' + empty)

if os.path.exists(images_split +'/train1' + empty):
    shutil.rmtree(images_split +'/train1' + empty)
os.makedirs(images_split +'/train1' + empty)

if os.path.exists(images_split +'/test' + empty):
    shutil.rmtree(images_split +'/test' + empty)
os.makedirs(images_split +'/test' + empty)

if os.path.exists(images_split +'/val' + empty):
    shutil.rmtree(images_split +'/val' + empty)
os.makedirs(images_split +'/val' + empty)

if os.path.exists(images_split +'/train' + blurred):
    shutil.rmtree(images_split +'/train' + blurred)
os.makedirs(images_split +'/train' + blurred)

if os.path.exists(images_split +'/train1' + blurred):
    shutil.rmtree(images_split +'/train1' + blurred)
os.makedirs(images_split +'/train1' + blurred)


if os.path.exists(images_split +'/test' + blurred):
    shutil.rmtree(images_split +'/test' + blurred)
os.makedirs(images_split +'/test' + blurred)

if os.path.exists(images_split +'/val' + blurred):
    shutil.rmtree(images_split +'/val' + blurred)
os.makedirs(images_split +'/val' + blurred)

# %%
# Creating partitions of the data after shuffeling
sra = "/content/drive/My Drive/DeepLearning/Project/dataset2/good"
srb = "/content/drive/My Drive/DeepLearning/Project/dataset2/empty"
src = "/content/drive/My Drive/DeepLearning/Project/dataset2/blurred"

srx = "/content/drive/My Drive/DeepLearning/Project/dataset2/train/good"
sry = "/content/drive/My Drive/DeepLearning/Project/dataset2/train/empty"
srz = "/content/drive/My Drive/DeepLearning/Project/dataset2/train/blurred"

# %%
#Good train_test split
allFileNames = os.listdir(sra)
np.random.shuffle(allFileNames)
test_FileNames, train_FileNames = np.split(np.array(allFileNames),
                                                          [int(len(allFileNames)*0.25)])

train_FileNames = [sra+'/'+ name for name in train_FileNames.tolist()]
test_FileNames = [sra+'/' + name for name in test_FileNames.tolist()]

print('Training: ', len(train_FileNames))
print('Testing: ', len(test_FileNames))

# Copy-pasting images
for name in train_FileNames:
    shutil.copy(name, "/content/drive/My Drive/DeepLearning/Project/dataset2/train/good")

for name in test_FileNames:
    shutil.copy(name, "/content/drive/My Drive/DeepLearning/Project/dataset2/test/good")
# Out:
# Training:  1098
# Testing:  366

# %%
#Good train_val split
allFileNames = os.listdir(srx)
np.random.shuffle(allFileNames)
test_FileNames, train_FileNames = np.split(np.array(allFileNames),
                                                          [int(len(allFileNames)*0.25)])

train_FileNames = [srx+'/'+ name for name in train_FileNames.tolist()]
test_FileNames = [srx+'/' + name for name in test_FileNames.tolist()]

print('Training: ', len(train_FileNames))
print('Validating: ', len(test_FileNames))

# Copy-pasting images
for name in train_FileNames:
    shutil.copy(name, "/content/drive/My Drive/DeepLearning/Project/dataset2/train1/good")

for name in test_FileNames:
    shutil.copy(name, "/content/drive/My Drive/DeepLearning/Project/dataset2/val/good")
# Out:
# Training:  824
# Validating:  274

# %%
#Empty train_test split
allFileNames = os.listdir(srb)
np.random.shuffle(allFileNames)
test_FileNames, train_FileNames = np.split(np.array(allFileNames),
                                                          [int(len(allFileNames)*0.25)])

train_FileNames = [srb+'/'+ name for name in train_FileNames.tolist()]
test_FileNames = [srb+'/' + name for name in test_FileNames.tolist()]

print('Training: ', len(train_FileNames))
print('Testing: ', len(test_FileNames))

# Copy-pasting images
for name in train_FileNames:
    shutil.copy(name, "/content/drive/My Drive/DeepLearning/Project/dataset2/train/empty")

for name in test_FileNames:
    shutil.copy(name, "/content/drive/My Drive/DeepLearning/Project/dataset2/test/empty")
# Out:
# Training:  1098
# Testing:  366

# %%
#Empty train_val split
allFileNames = os.listdir(sry)
np.random.shuffle(allFileNames)
test_FileNames, train_FileNames = np.split(np.array(allFileNames),
                                                          [int(len(allFileNames)*0.25)])

train_FileNames = [sry+'/'+ name for name in train_FileNames.tolist()]
test_FileNames = [sry+'/' + name for name in test_FileNames.tolist()]

print('Training: ', len(train_FileNames))
print('Validating: ', len(test_FileNames))

# Copy-pasting images
for name in train_FileNames:
    shutil.copy(name, "/content/drive/My Drive/DeepLearning/Project/dataset2/train1/empty")

for name in test_FileNames:
    shutil.copy(name, "/content/drive/My Drive/DeepLearning/Project/dataset2/val/empty")
# Out:
# Training:  824
# Validating:  274

# %%
#Blurred train_test split
allFileNames = os.listdir(src)
np.random.shuffle(allFileNames)
test_FileNames, train_FileNames = np.split(np.array(allFileNames),
                                                          [int(len(allFileNames)*0.25)])

train_FileNames = [src+'/'+ name for name in train_FileNames.tolist()]
test_FileNames = [src+'/' + name for name in test_FileNames.tolist()]

print('Training: ', len(train_FileNames))
print('Testing: ', len(test_FileNames))

# Copy-pasting images
for name in train_FileNames:
    shutil.copy(name, "/content/drive/My Drive/DeepLearning/Project/dataset2/train/blurred")

for name in test_FileNames:
    shutil.copy(name, "/content/drive/My Drive/DeepLearning/Project/dataset2/test/blurred")
# Out:
# Training:  1098
# Testing:  366

# %%
#Blurred train_val split
allFileNames = os.listdir(srz)
np.random.shuffle(allFileNames)
test_FileNames, train_FileNames = np.split(np.array(allFileNames),
                                                          [int(len(allFileNames)*0.25)])

train_FileNames = [srz+'/'+ name for name in train_FileNames.tolist()]
test_FileNames = [srz+'/' + name for name in test_FileNames.tolist()]

print('Training: ', len(train_FileNames))
print('Validating: ', len(test_FileNames))

# Copy-pasting images
for name in train_FileNames:
    shutil.copy(name, "/content/drive/My Drive/DeepLearning/Project/dataset2/train1/blurred")

for name in test_FileNames:
    shutil.copy(name, "/content/drive/My Drive/DeepLearning/Project/dataset2/val/blurred")
# Out:
# Training:  824
# Validating:  274

# %%
#Resize images to 600 x 600
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_dir = "/content/drive/My Drive/DeepLearning/Project/dataset2/train1/"
validation_dir = "/content/drive/My Drive/DeepLearning/Project/dataset2/val/"
test_dir = "/content/drive/My Drive/DeepLearning/Project/dataset2/test/"

# All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        # This is the target directory
        train_dir,
        # All images will be resized to 700x700
        target_size=(600, 600),
        batch_size=20,
        # Since we use binary_crossentropy loss, we need binary labels
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(600, 600),
        batch_size=20,
        class_mode='categorical')

test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(600, 600),
        batch_size=20,
        class_mode='categorical')
# Out:
# Found 2472 images belonging to 3 classes.
# Found 822 images belonging to 3 classes.
# Found 1098 images belonging to 3 classes.

# %%
from keras.applications.vgg16 import VGG16
from keras.models import Model
from keras.models import Input
from keras.models import Sequential
from keras import optimizers
from keras.layers import Dense,Flatten,Activation, Dropout
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
image_w, image_h = 600,600
model = Sequential()
model = applications.VGG16(weights = "imagenet", include_top=False, input_shape = (image_w, image_h, 3))

last = model.output
x = Flatten()(last)
x = Dense(256, activation='relu', name='new_fc1', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = Dropout(0.5)(x)
preds = Dense(3, activation='softmax')(x)

model = Model(model.input, preds)

model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 600, 600, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 600, 600, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 600, 600, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 300, 300, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 300, 300, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 300, 300, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 150, 150, 128)     0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 150, 150, 256)     295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 150, 150, 256)     590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 150, 150, 256)     590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 75, 75, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 75, 75, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 75, 75, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 75, 75, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 37, 37, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 37, 37, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 37, 37, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 37, 37, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 18, 18, 512)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 165888)            0
# _________________________________________________________________
# new_fc1 (Dense)              (None, 256)               42467584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 57,183,043
# Trainable params: 57,183,043
# Non-trainable params: 0
# _________________________________________________________________

# %%
for layer in model.layers:
  layer.trainable = True
    
for i, layer in enumerate(model.layers):
    print(i, layer.name, layer.trainable)
# Out:
# 0 input_2 True
# 1 block1_conv1 True
# 2 block1_conv2 True
# 3 block1_pool True
# 4 block2_conv1 True
# 5 block2_conv2 True
# 6 block2_pool True
# 7 block3_conv1 True
# 8 block3_conv2 True
# 9 block3_conv3 True
# 10 block3_pool True
# 11 block4_conv1 True
# 12 block4_conv2 True
# 13 block4_conv3 True
# 14 block4_pool True
# 15 block5_conv1 True
# 16 block5_conv2 True
# 17 block5_conv3 True
# 18 block5_pool True
# 19 flatten_2 True
# 20 new_fc1 True
# 21 dropout_2 True
# 22 dense_2 True

# %%
model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(lr=0.00003), metrics=['accuracy'])

# %%
es = EarlyStopping(monitor='val_acc', verbose=2, patience=25)
filepath = "./VGG16_model4.h5"
mc = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True)

# %%
VGG16_model = model.fit(train_generator, validation_data = validation_generator, epochs = 30, verbose=2, callbacks=[es,mc])
# Out:
# Epoch 1/30
#  - 178s - loss: 3.5092 - acc: 0.7005 - val_loss: 2.0390 - val_acc: 0.8224
#
# Epoch 00001: val_acc improved from -inf to 0.82238, saving model to ./VGG16_model4.h5
# Epoch 2/30
#  - 166s - loss: 1.5954 - acc: 0.8421 - val_loss: 1.2933 - val_acc: 0.8783
#
# Epoch 00002: val_acc improved from 0.82238 to 0.87835, saving model to ./VGG16_model4.h5
# Epoch 3/30
#  - 166s - loss: 1.1159 - acc: 0.9013 - val_loss: 1.0132 - val_acc: 0.9270
#
# Epoch 00003: val_acc improved from 0.87835 to 0.92701, saving model to ./VGG16_model4.h5
# Epoch 4/30
#  - 166s - loss: 0.8882 - acc: 0.9407 - val_loss: 0.8852 - val_acc: 0.9112
#
# Epoch 00004: val_acc did not improve from 0.92701
# Epoch 5/30
#  - 166s - loss: 0.7614 - acc: 0.9548 - val_loss: 0.8144 - val_acc: 0.9100
#
# Epoch 00005: val_acc did not improve from 0.92701
# Epoch 6/30
#  - 166s - loss: 0.6771 - acc: 0.9578 - val_loss: 0.6891 - val_acc: 0.9343
#
# Epoch 00006: val_acc improved from 0.92701 to 0.93431, saving model to ./VGG16_model4.h5
# Epoch 7/30
#  - 166s - loss: 0.5839 - acc: 0.9751 - val_loss: 0.6680 - val_acc: 0.9270
#
# Epoch 00007: val_acc did not improve from 0.93431
# Epoch 8/30
#  - 166s - loss: 0.5332 - acc: 0.9766 - val_loss: 0.6928 - val_acc: 0.9015
#
# Epoch 00008: val_acc did not improve from 0.93431
# Epoch 9/30
#  - 166s - loss: 0.4637 - acc: 0.9855 - val_loss: 0.5890 - val_acc: 0.9355
#
# Epoch 00009: val_acc improved from 0.93431 to 0.93552, saving model to ./VGG16_model4.h5
# Epoch 10/30
#  - 166s - loss: 0.5006 - acc: 0.9655 - val_loss: 0.5963 - val_acc: 0.9234
#
# Epoch 00010: val_acc did not improve from 0.93552
# Epoch 11/30
#  - 166s - loss: 0.3947 - acc: 0.9935 - val_loss: 0.5584 - val_acc: 0.9319
#
# Epoch 00011: val_acc did not improve from 0.93552
# Epoch 12/30
#  - 166s - loss: 0.3802 - acc: 0.9888 - val_loss: 0.6046 - val_acc: 0.8929
#
# Epoch 00012: val_acc did not improve from 0.93552
# Epoch 13/30
#  - 166s - loss: 0.3332 - acc: 0.9948 - val_loss: 0.5093 - val_acc: 0.9453
#
# Epoch 00013: val_acc improved from 0.93552 to 0.94526, saving model to ./VGG16_model4.h5
# Epoch 14/30
#  - 166s - loss: 0.3068 - acc: 0.9948 - val_loss: 0.4867 - val_acc: 0.9416
#
# Epoch 00014: val_acc did not improve from 0.94526
# Epoch 15/30
#  - 166s - loss: 0.3166 - acc: 0.9827 - val_loss: 0.4901 - val_acc: 0.9331
#
# Epoch 00015: val_acc did not improve from 0.94526
# Epoch 16/30
#  - 166s - loss: 0.2881 - acc: 0.9911 - val_loss: 0.4536 - val_acc: 0.9258
#
# Epoch 00016: val_acc did not improve from 0.94526
# Epoch 17/30
#  - 166s - loss: 0.2897 - acc: 0.9879 - val_loss: 0.5175 - val_acc: 0.8905
#
# Epoch 00017: val_acc did not improve from 0.94526
# Epoch 18/30
#  - 166s - loss: 0.2627 - acc: 0.9887 - val_loss: 0.4323 - val_acc: 0.9404
#
# Epoch 00018: val_acc did not improve from 0.94526
# Epoch 19/30
#  - 166s - loss: 0.2510 - acc: 0.9887 - val_loss: 0.4069 - val_acc: 0.9367
#
# Epoch 00019: val_acc did not improve from 0.94526
# Epoch 20/30
#  - 166s - loss: 0.2133 - acc: 0.9984 - val_loss: 0.3877 - val_acc: 0.9465
#
# Epoch 00020: val_acc improved from 0.94526 to 0.94647, saving model to ./VGG16_model4.h5
# Epoch 21/30
#  - 166s - loss: 0.2059 - acc: 0.9952 - val_loss: 0.4501 - val_acc: 0.9367
#
# Epoch 00021: val_acc did not improve from 0.94647
# Epoch 22/30
#  - 166s - loss: 0.2445 - acc: 0.9806 - val_loss: 0.4458 - val_acc: 0.9416
#
# Epoch 00022: val_acc did not improve from 0.94647
# Epoch 23/30
#  - 166s - loss: 0.1880 - acc: 0.9972 - val_loss: 0.4404 - val_acc: 0.9258
#
# Epoch 00023: val_acc did not improve from 0.94647
# Epoch 24/30
#  - 166s - loss: 0.1766 - acc: 0.9984 - val_loss: 0.5516 - val_acc: 0.9221
#
# Epoch 00024: val_acc did not improve from 0.94647
# Epoch 25/30
#  - 165s - loss: 0.1819 - acc: 0.9929 - val_loss: 0.4843 - val_acc: 0.9209
#
# Epoch 00025: val_acc did not improve from 0.94647
# Epoch 26/30
#  - 165s - loss: 0.1707 - acc: 0.9935 - val_loss: 0.4716 - val_acc: 0.9294
#
# Epoch 00026: val_acc did not improve from 0.94647
# Epoch 27/30
#  - 166s - loss: 0.1536 - acc: 0.9972 - val_loss: 0.3710 - val_acc: 0.9392
#
# Epoch 00027: val_acc did not improve from 0.94647
# Epoch 28/30
#  - 165s - loss: 0.1874 - acc: 0.9827 - val_loss: 0.4177 - val_acc: 0.9124
#
# Epoch 00028: val_acc did not improve from 0.94647
# Epoch 29/30
#  - 166s - loss: 0.1767 - acc: 0.9911 - val_loss: 0.3451 - val_acc: 0.9270
#
# Epoch 00029: val_acc did not improve from 0.94647
# Epoch 30/30
#  - 165s - loss: 0.1768 - acc: 0.9887 - val_loss: 0.3609 - val_acc: 0.9307
#
# Epoch 00030: val_acc did not improve from 0.94647

# %% [markdown]
# # **Evaluate Model**

# %%
from keras.models import load_model
import numpy
import os
# %cd /content/drive/My Drive/DeepLearning/Project/dataset2
# Out:
# /content/drive/My Drive/DeepLearning/Project/dataset2

# %%
final_model_VGG16 = tf.keras.models.load_model('./VGG16_model4.h5')

# %%
# evaluate the model on validation set
val_scores = []
val_scores_1 = final_model_VGG16.evaluate(validation_generator, verbose=0)
print("%s: %.2f%%" % (final_model_VGG16.metrics_names[1], val_scores_1[1]*100))
val_scores.append(val_scores_1[1] * 100)
# Out:
# acc: 94.65%

# %%
# evaluate the model
finalscores = []
final_scores_1 = final_model_VGG16.evaluate(test_generator, verbose=0)
print("%s: %.2f%%" % (final_model_VGG16.metrics_names[1], final_scores_1[1]*100))
finalscores.append(final_scores_1[1] * 100)
# Out:
# acc: 94.81%

# %%
# Predict class
predictions = model.predict_generator(test_generator)
# Get most likely class
predicted_classes = numpy.argmax(predictions, axis=1)

# %%
true_classes = test_generator.classes
class_labels = list(test_generator.class_indices.keys())

# %%
import sklearn
from sklearn import metrics

report = metrics.classification_report(true_classes, predicted_classes, target_names=class_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#      blurred       0.33      0.32      0.32       366
#        empty       0.30      0.31      0.31       366
#         good       0.33      0.33      0.33       366
#
#     accuracy                           0.32      1098
#    macro avg       0.32      0.32      0.32      1098
# weighted avg       0.32      0.32      0.32      1098

# %%
import itertools    
import pandas as pd
categorical_preds = pd.DataFrame(predicted_classes).idxmax(axis=1)
confusion_matrix = sklearn.metrics.confusion_matrix(true_classes, predicted_classes)

#To get better visual of the confusion matrix:
def plot_confusion_matrix(cm, classes, 
                          normalize=False, 
                          title="Confusion matrix",
                          cmap=plt.cm.Blues):
 
#Add Normalization Option
   if normalize:
     cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
     print('Normalized confusion matrix')
   else:
     print('Confusion matrix, without normalization')
 
# print(cm)
   plt.imshow(cm, interpolation='nearest', cmap=cmap)
   plt.title(title)
   plt.colorbar()
   tick_marks = np.arange(len(classes))
   plt.xticks(tick_marks, classes, rotation=45)
   plt.yticks(tick_marks, classes)
 
   fmt = '.2f' if normalize else 'd'
   thresh = cm.max() / 2.
   for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      plt.text(j, i, format(cm[i, j], fmt), horizontalalignment='center', color='white' if cm[i, j] > thresh else 'black')
 
   plt.tight_layout()
   plt.ylabel('True label')
   plt.xlabel('Predicted label')

# %%
plot_confusion_matrix(confusion_matrix,['blurred','empty','good'], normalize = True)
# Out:
# Normalized confusion matrix
